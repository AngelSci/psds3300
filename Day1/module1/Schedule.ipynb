# %% [markdown]
# # Module One: Introduction to Interactive Visualizations with Shiny
#
#
# ## Topics covered
# - Introduction to Shiny
# - App architecture
# - Deploying apps
# - Reactive Programming
#
#
# ## Notebook Shortcuts
#
# (Please go through the notebooks in this order)
#
# ### labs
# - [Introduction to Shiny](labs/L1_AdvViz_Intro.ipynb)
#
#
# ### practices
# - [L1_Practice_UI](practices/L1_Practice_UI.ipynb)
# - [L1_Practice_Server](practices/L1_Practice_Server.ipynb)
#
#
# ### exercises
# - [L1_Exercise](exercises/L1_Exercise.ipynb)
#
#
# ## Readings
#
# The following are some useful references for Shiny:
#
# - [shiny.rstudio.com](https://shiny.rstudio.com)
# - [Shiny function reference](http://shiny.rstudio.com/reference/shiny/latest/)
# - [Shiny articles](http://shiny.rstudio.com/articles/)
# - [Shiny R package](https://cran.r-project.org/web/packages/shiny/shiny.pdf)
#
# The following are good reads for dashboard layouts and web layouts in general:
#
# - [Dashboard Layouts](https://www.perceptualedge.com/articles/Whitepapers/Formatting_and_Layout_Matter.pdf)
# - [User Interface Patterns](https://www.uxpin.com/studio/blog/web-layout-best-practices-12-timeless-ui-patterns-explained/)
# - [Visual Hierarchy for Design](https://99designs.com/blog/tips/6-principles-of-visual-hierarchy/)
#
#
# ## Video topics
# - **Concept Video**: Introduction to Shiny
#
#
# ## Suggested Schedule
#
# ### Monday
# - **Concept Video**: Introduction to Shiny
# - **Lab Notebook**: L1_AdvViz_Intro.ipynb
# - **Practice Notebook**: L1_Practice_UI.ipynb
# - **Practice Notebook**: L1_Practice_Server.ipynb
#
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Friday/Saturday/Sunday
# - **Exercise**: L1_Exercise.ipynb
