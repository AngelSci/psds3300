# %% [markdown]
# # Module Two: Customizing Interactive Visualizations with Shiny
#
#
# ## Topics covered
# - Building layouts, Widgets
# - Dashboard design in Shiny
# - Custom UI with HTML and CSS
#
#
# ## Notebook Shortcuts
#
# (Please go through the notebooks in this order)
#
# ### labs
# - [Layouts in Shiny](labs/L2_Layouts.ipynb)
# - [Widgets in Shiny](labs/L2_Widgets.ipynb)
# - [HTML and CSS](labs/L2_HTML.ipynb)
#
#
# ### practices
# - [L2_Practice_Layout](practices/L2_Practice_Layout.ipynb)
# - [L2_Practice_Dashboard](practices/L2_Practice_Dashboard.ipynb)
#
#
# ### exercises
# - [L2_Exercise](exercises/L2_Exercise.ipynb)
#
#
# ## Readings
#
# The following are some useful references for creating dashboards in Shiny:
#
# - [shinydashboard package](https://cran.r-project.org/web/packages/shinydashboard/shinydashboard.pdf)
# - [shinydashboard functions reference](https://www.rdocumentation.org/packages/shinydashboard/versions/0.6.1)
#
# - [HTML basics](https://www.w3schools.com/html/html_basic.asp)
#
# The following are good links to get familiar with the dashboard design and general interactive visualization design process.
#
# - [Examples of Dashboard Design](http://www.hongkiat.com/blog/dashboard-design-examples-resources/)
# - [Sample Tool Design Process 1](labs/Hoque_et_al-2014-Computer_Graphics_Forum.pdf)
# - [Tool web site](https://www.cs.ubc.ca/cs-research/lci/research-groups/natural-language-processing/convis/)
#
#
# - [Sample Tool Design Process 2](labs/Poco_et_al-2014-Computer_Graphics_Forum.pdf)
#
#
#
# ## Video topics
# - **Concept Video**: Layouts in Shiny
#
#
# ## Suggested Schedule
#
# ### Monday
# - **Concept Video**: Layouts in Shiny
# - **Lab Notebooks**: L2_Layouts.ipynb, L2_Widgets.ipynb, L2_HTML.ipynb
# - **Practice Notebooks**: L2_Practice_Layout.ipynb, L2_Practice_Dashboard.ipynb
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Friday/Saturday/Sunday
# - **Exercise**: L2_Exercise.ipynb
