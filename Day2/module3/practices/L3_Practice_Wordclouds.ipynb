# %% [markdown]
# # Practice - Word Clouds

# %% [markdown]
# In this practice, we will create a Shiny app to visualize word cloud and interactively remove words and change its options to analyze text.
#
# We will use a preprocessed screenplay from the season one episode one of the Game of Thrones. The screenplay is edited to remove all scene descriptions; only actors' and actresses' lines are kept. We will visualize the script and also the number of lines per character. First, load the data and see it.

# %%
library(tm)
library(wordcloud)
library(RColorBrewer)

filePath <- "gotS1E1processed.txt"
text <- readLines(filePath)
# Load the data as a corpus
docs <- Corpus(VectorSource(text))
inspect(docs)
# Out:
# Loading required package: NLP
# Loading required package: RColorBrewer
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 330
#
#   [1] WAYMAR ROYCE: What d'you expect? They're savages. One lot steals a goat from another lot and before you know it, they're ripping each other to pieces.
#   [2] WILL: I've never seen wildlings do a thing like this. I've never seen a thing like this, not ever in my life.
#   [3] WAYMAR ROYCE: How close did you get?
#   [4] WILL: Close as any man would.
#   [5] GARED: We should head back to the wall.
#   [6] ROYCE: Do the dead frighten you?
#   [7] GARED: Our orders were to track the wildlings. We tracked them. They won't trouble us no more.
#   [8] ROYCE: You don't think he'll ask us how they died? Get back on your horse.
#   [9] WILL: Whatever did it to them could do it to us. They even killed the children.
#  [10] ROYCE: It's a good thing we're not children. You want to run away south, run away. Of course, they will behead you as a deserter . If I don't catch you first. Get back on your horse. I won't say it again.
#  [11] ROYCE: Your dead men seem to have moved camp.
#  [12] WILL: They were here.
#  [13] GARED: See where they went.
#  [14] ROYCE: What is it?
#  [15] GARED: It's .
#  [16] JON: Go on. Father's watching.
#  [17] JON: And your mother.
#  [18] SEPTA MORDANE: Fine work, as always. Well done.
#  [19] SANSA: Thank you.
#  [20] SEPTA MORDANE: I love the detail that you've managed to get in this corners. . Quite beautiful . the stitching .
#  [21] NED: And which one of you was a marksman at ten? Keep practicing, Bran. Go on.
#  [22] JON: Don't think too much, Bran.
#  [23] ROBB: Relax your bow arm.
#  [24] JON/ROBB: Quick, Bran, faster!
#  [25] CASSEL: Lord Stark. My lady. A guardsman just rode in from the hills. They've captured a deserter from the Night's Watch.
#  [26] NED: Get the lads to saddle their horses.
#  [27] CATELYN: Do you have to?
#  [28] NED: He swore an oath, Cat.
#  [29] CASSEL: The law is law, my lady.
#  [30] NED: Tell Bran he's coming, too.
#  [31] CATELYN: Ned. Ten is too young to see such things.
#  [32] NED: He won't be a boy forever. And winter is coming.
#  [33] ROBB: Lad, go run back and get the rest.
#  [34] WILL: White Walkers. I saw the White Walkers. White Walkers. The White Walkers, I saw them.
#  [35] WILL: I know I broke my oath. And I know I'm a deserter. I should have gone back to the Wall and warned them. But I saw what I saw. I saw the White Walkers. People need to know. If you can get word to my family, tell them I'm no coward. Tell them I'm sorry.
#  [36] WILL: Forgive me, lord.
#  [37] NED: In the name of Robert of the House Baratheon, first of his name .
#  [38] JON: Don't look away.
#  [39] NED: King of the Andals and the First Men .
#  [40] JON: Father will know if you do.
# [322] JAIME: Are you completely mad?
# [323] CERSEI: He saw us.
# [324] JAIME: It's all right. It's all right.
# [325] CERSEI: He saw us!
# [326] JAIME: I heard you the first time. (To BRAN) Quite the little climber, aren't you? How old are you, boy?
# [327] BRAN: Ten.
# [328] JAIME: Ten.
# [329] JAIME: The things I do for love.
# [330]

# %% [markdown]
# Before doing anything else, we will create two documents, one containing lines only, other one containing character names only. For that, we'll define our own text mining function, and use it to separate lines from names.

# %%
# This is our function definition; sub replaces a string with another one. 
# Here we remove a "pattern" by replacing it with nothing ("")

SepName <- content_transformer(function (x , pattern ) sub(pattern, "", x))
    
# Let's call it two times, to replace names and lines:
# everything before ":", and everything after ":" 
gotlines <- tm_map(docs, SepName, ".*:")
gotnames <- tm_map(docs, SepName, ":.*")

# let's look at lines only
inspect(gotlines)
# Out:
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 330
#
#   [1]  What d'you expect? They're savages. One lot steals a goat from another lot and before you know it, they're ripping each other to pieces.
#   [2]  I've never seen wildlings do a thing like this. I've never seen a thing like this, not ever in my life.
#   [3]  How close did you get?
#   [4]  Close as any man would.
#   [5]  We should head back to the wall.
#   [6]  Do the dead frighten you?
#   [7]  Our orders were to track the wildlings. We tracked them. They won't trouble us no more.
#   [8]  You don't think he'll ask us how they died? Get back on your horse.
#   [9]  Whatever did it to them could do it to us. They even killed the children.
#  [10]  It's a good thing we're not children. You want to run away south, run away. Of course, they will behead you as a deserter . If I don't catch you first. Get back on your horse. I won't say it again.
#  [11]  Your dead men seem to have moved camp.
#  [12]  They were here.
#  [13]  See where they went.
#  [14]  What is it?
#  [15]  It's .
#  [16]  Go on. Father's watching.
#  [17]  And your mother.
#  [18]  Fine work, as always. Well done.
#  [19]  Thank you.
#  [20]  I love the detail that you've managed to get in this corners. . Quite beautiful . the stitching .
#  [21]  And which one of you was a marksman at ten? Keep practicing, Bran. Go on.
#  [22]  Don't think too much, Bran.
#  [23]  Relax your bow arm.
#  [24]  Quick, Bran, faster!
#  [25]  Lord Stark. My lady. A guardsman just rode in from the hills. They've captured a deserter from the Night's Watch.
#  [26]  Get the lads to saddle their horses.
#  [27]  Do you have to?
#  [28]  He swore an oath, Cat.
#  [29]  The law is law, my lady.
#  [30]  Tell Bran he's coming, too.
#  [31]  Ned. Ten is too young to see such things.
#  [32]  He won't be a boy forever. And winter is coming.
#  [33]  Lad, go run back and get the rest.
#  [34]  White Walkers. I saw the White Walkers. White Walkers. The White Walkers, I saw them.
#  [35]  I know I broke my oath. And I know I'm a deserter. I should have gone back to the Wall and warned them. But I saw what I saw. I saw the White Walkers. People need to know. If you can get word to my family, tell them I'm no coward. Tell them I'm sorry.
#  [36]  Forgive me, lord.
#  [37]  In the name of Robert of the House Baratheon, first of his name .
#  [38]  Don't look away.
#  [39]  King of the Andals and the First Men .
#  [40]  Father will know if you do.
#  [41]  Lord of the Seven Kingdoms and protector of the realm, I, Eddard of the House Stark, Lord of Winterfell and Warden of the North, sentence you to die.
# [306] DAENERYS      KHAL DROGO    DAENERYS      KHAL DROGO    THE HOUND
# [311] TYRION        THE HOUND     TYRION        THE HOUND     ROBERT
# [316] NED           ROBERT        NED           ROBERT        BRAN
# [321] CERSEI        JAIME         CERSEI        JAIME         CERSEI
# [326] JAIME         BRAN          JAIME         JAIME

# %% [markdown]
# Now, we need to do the text processing on ```gotlines``` to remove punctuation and white space, and convert to lower case, and remove stopwords just like we have seen in the lab notebook.
# **It's your turn:**

# %%
gotlines <- # YOUR CODE 
gotlines <- # YOUR CODE 
gotlines <- # YOUR CODE 
gotlines <- # YOUR CODE 

inspect(gotlines)

# %% [markdown]
# Now we will compute the word frequencies and plot the word cloud.
# **It's your turn:**

# %%
dtm1 <- # YOUR CODE 
m1 <- # YOUR CODE 
v1 <-# YOUR CODE 
d1 <- # YOUR CODE 
head(d1, 30)

set.seed(1234)
wordcloud(words = d1$word, freq = d1$freq, min.freq = 5,
          max.words=100, random.order=FALSE, rot.per=0, 
          colors=brewer.pal(8, "Dark2"))

# %% [markdown]
# Now, visualize the **```gotnames```** as a word cloud. Since it only contains character names, you do not need to do any text preprocessing. Just compute the frequencies and plot them.
#
# #### <span style='background:yellow'>It's your turn</span>

# %%
# YOUR CODE HERE
# ----------------

# %% [markdown]
# Which two characters have the most lines ?

# %% [markdown]
# ### Interactive Word Cloud in Shiny
#
# Now, we will create an app to show the word cloud. First we will create a static app with no interaction. We need a simple layout with one plot.

# %% [raw]
# # SAVE THIS CODE into app.R under module3-wordcloud1 and DEPLOY
#
# library(shiny)
# library(tm)
# library(wordcloud)
# library(RColorBrewer)
#
# # read the text file
# text <- readLines("gotS1E1processed.txt")
# # Load the data as a corpus
# docs <- Corpus(VectorSource(text))
# # all this processing needs to be done once.
# SepName <- content_transformer(function (x , pattern ) sub(pattern, "", x))
# gotlines <- # YOUR CODE
# gotnames <- # YOUR CODE
# # preprocessing
# gotlines <- # YOUR CODE
# gotlines <- # YOUR CODE
# gotlines <- # YOUR CODE
# gotlines <- # YOUR CODE
# set.seed(1234)
#
# got_ui <- fluidPage(
#
#    titlePanel("GoT Word Cloud"),
#
#    sidebarLayout(
#      sidebarPanel(helpText("Game of Thrones Season 1 Episode 1.")),
#      mainPanel(plotOutput("gotplot"))
#    )
# )
#
#
# got_server <- function(input, output){
#
# output$gotplot <- renderPlot ({
#
#    # the following could be also placed outside the render function,
#    # but we will recompute this in the next version of this app.
#
#    dtm1 <- TermDocumentMatrix(gotlines)
#    m1 <- as.matrix(dtm1)
#    v1 <- sort(rowSums(m1),decreasing=TRUE)
#    d1 <- data.frame(word = names(v1),freq=v1)
#
#    wordcloud(words = d1$word, freq = d1$freq, min.freq = 5,
#           max.words=100, random.order=FALSE, rot.per=0,
#           colors=brewer.pal(8, "Dark2"))
#  })
#
# }
#
# shinyApp(ui=got_ui, server=got_server)

# %%
#DEPLOY TO SHINY SERVER
dir <- getwd() #This gets the current Working Directory
course <- "DATA-SCI-8654" #This is to specify the course path for the shiny server
folder <- "module3-wordcloud1" #This specifies the folder name to copy

system(sprintf("/usr/local/bin/shiny_deploy %s %s %s", course, dir,folder), 
       intern = TRUE,
       ignore.stdout = FALSE, 
       ignore.stderr = FALSE,
       wait = TRUE, 
       input = NULL)

# %% [markdown]
# ** Now we will modify this code to get user input for the minimum frequency and maximum number of words. **
# Let's have two sliders for these:

# %% [raw]
# # REPLACE UI like this:
#
# got_ui <- fluidPage(
#
#    titlePanel("GoT Word Cloud"),
#
#    sidebarLayout(
#      sidebarPanel(helpText("Game of Thrones Season 1 Episode 1."),
#                   sliderInput("maxnum","Maximum number of words:",min=10, max=300, step=10, value=100),
#                   sliderInput("minfreq","Minimum frequency:",min=1, max=30, step=1, value=5)
#                  ),
#      mainPanel(plotOutput("gotplot"))
#    )
# )

# %% [raw]
# # REPLACE SERVER like this and write YOUR CODE for wordcloud depending on the sliders
#
# got_server <- function(input, output){
#
# output$gotplot <- renderPlot ({
#
#    # the following could be also placed outside the render function,
#    # but we will recompute this in the next version of this app.
#
#    dtm1 <- TermDocumentMatrix(gotlines)
#    m1 <- as.matrix(dtm1)
#    v1 <- sort(rowSums(m1),decreasing=TRUE)
#    d1 <- data.frame(word = names(v1),freq=v1)
#
#    ## YOUR CODE HERE
#  })
#
# }
#
# shinyApp(ui=got_ui, server=got_server)

# %% [markdown]
# Now, we will have check boxes to remove words from the word cloud. For this, we will display the top 20 words, and let user to choose to include or exclude them from the visualization.

# %% [raw]
# # REPLACE THE FIRST PART of the app like this
#
# library(shiny)
# library(tm)
# library(wordcloud)
# library(RColorBrewer)
#
# # read the text file
# text <- readLines("gotS1E1processed.txt")
# # Load the data as a corpus
# docs <- Corpus(VectorSource(text))
# # all this processing needs to be done once.
# SepName <- content_transformer(function (x , pattern ) sub(pattern, "", x))
#
# ## YOUR CODE HERE for preprocesing
# set.seed(1234)
#
# dtm1 <- TermDocumentMatrix(gotlines)
# m1 <- as.matrix(dtm1)
# v1 <- sort(rowSums(m1),decreasing=TRUE)
# d1 <- data.frame(word = names(v1),freq=v1)
#
# wlist <- d1$word[1:20]

# %% [raw]
# # REPLACE UI like this:
#
# got_ui <- fluidPage(
#
#    titlePanel("GoT Word Cloud"),
#
#    sidebarLayout(
#      sidebarPanel(helpText("Game of Thrones Season 1 Episode 1."),
#                   sliderInput("maxnum","Maximum number of words:",min=10, max=300, step=10, value=100),
#                   sliderInput("minfreq","Minimum frequency:",min=1, max=30, step=1, value=5),
#                   checkboxGroupInput("check", "Remove words", choices = wlist)
#                  ),
#      mainPanel(plotOutput("gotplot"))
#    )
# )

# %% [raw]
# # REPLACE SERVER like this:
#
# got_server <- function(input, output){
#
# output$gotplot <- renderPlot ({
#
#    gotlines <- tm_map(gotlines, removeWords, input$check)
#
# # YOUR CODE HERE to compute word frequencies.
#
# # YOUR CODE HERE to visualize wordcloud
#
# })
#
# }
#
# shinyApp(ui=got_ui, server=got_server)

# %% [markdown]
# You should see an interface similar to this:
#
# <img src="../images/got.png">
