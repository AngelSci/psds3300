# %% [markdown]
# # Module Three: Cognition and Visual Perception
#
#
# ## Topics covered
# - Cognitive and sensory systems
# - Sensory-level mechanisms in visual perception
# - Practice: Bubble charts and word clouds
#
#
# ## Notebook Shortcuts
#
# (Please go through the notebooks in this order)
#
# ### labs
# - [Bubble charts in Shiny](labs/L3_Bubble.ipynb)
# - [Word clouds in Shiny](labs/L3_Wordcloud.ipynb)
#
#
# ### practices
# - [L3_Practice_Bubblecharts](practices/L3_Practice_Bubblecharts.ipynb)
# - [L3_Practice_Wordclouds](practices/L3_Practice_Wordclouds.ipynb)
#
#
# ### exercises
# - [L3_Exercise](exercises/L3_Exercise.ipynb)
#
#
# ## Readings
#
# ### The following are some light reading on Gestalt theory and visual perception.
#
# - [Refresher: Gestalt Theory](https://www.smashingmagazine.com/2014/03/design-principles-visual-perception-and-the-principles-of-gestalt/)
# - [Visual Perception and Memory](http://vanseodesign.com/web-design/visual-perception-memory/)
#
# ### Cognitive Load Theory
#
# [Cognitive Load Theory](labs/kirschner_cog_load.pdf) Paul Kirschner is an American born learning scientist who made his career in the Netherlands. The article focuses on cognitive load theory from the point of view of human learning.  We select this reading because, in many respects, when you are designing visualizations you are working to construct interactive environments that support learning.  As our videos suggest this week, too much information can overload people. And making connections to the broader context of information that your stakeholders have access to is one mechanism for managing load.
#
# [This report](http://oceansofdata.org/sites/oceansofdata.org/files/Visualizing-Oceans-Data-Report-Dec2013.pdf) is a good example of how much thought and design goes into the visualization design regarding many aspects of human visual perception that we have seen before, and the cognitive load. Please read pages 20-39 for discussion.
#
#
# ## Video topics
# - **Concept Video**: [1] Cognitive and Social Systems, Perception and Working Memory
#
# ## Suggested Schedule
#
# ### Monday
# - **Concept Videos**: [1]
# - **Lab Notebooks**: L3_Bubble.ipynb, L3_Wordcloud.ipynb
# - **Practice Notebooks**: L3_Practice_Bubblecharts.ipynb, L3_Practice_Wordclouds.ipynb
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Friday/Saturday/Sunday
# - **Exercise**: L3_Exercise.ipynb
