# %% [markdown]
# # Welcome to PSDS 3300
#
# ## Advanced Visualization and Communication 1
#
# __Synopsis:__ The course covers the fundamentals of current visualization concepts and technologies as well as infographic and interactive visualization design.
# Unlike many data visualization courses,
# this course focuses on principles of visualization design and the grammar of graphics as they can be applied to combining art & technology to tell data stories.
# These principles are then implemented in popular contemporary visualization technologies.
# Students will develop an advanced knowledge of the appropriate selection, modeling, and evaluation of data visualizations.
#
# __Course Design:__ This is a 3 credit hour / 5 day course.
# This entire course is delivered in an instructor-led format.
# The final day of the course includes significant time for the instructor to lead the students through the final course project.
#
# __Instructor Read-Aloud:__
#    * [To be read by the instructor, to the class, at the start of Day 1](https://indigo.sgn.missouri.edu/static/info/CourseKickOff_ReadAloud.pdf)

# %% [markdown]
# ## Getting Started - Returning PSDS Student
#
# You should have previously been issued a PSDS User ID and password.
#
# If your password has been reset, it will have a temporary value: `pa$$.####`
# and you will need to follow the password reset instructions below.
#
# Otherwise, you may continue to use your PSDS credentials.
# Speak with the instructor if you need to request a password reset (i.e. you forgot your previous password).

# %% [markdown]
# ## Course Schedule
#
# To begin the course work of each day, please click the heading in the table below.
# Each day will be available to students by 6am on that instruction day.
# Students are able to pull new course content as demonstrated by the instructor and shown [here](./module1/resources/PullingFromGit.ipynb).
#
# <table border=1 cellpadding='5px'>
#     <tr>
#         <th align='center'>[Day 1](Day1/Schedule.ipynb) Instructor Led</th>
#         <th align='center'>[Day 2](Day2/Schedule.ipynb) Instructor Led</th>
#         <th align='center'>[Day 3](Day3/Schedule.ipynb) Instructor Led</th>
#         <th align='center'>[Day 4](Day4/Schedule.ipynb) Instructor Led</th>
#         <th align='center'>[Day 5](Day5/Schedule.ipynb) Instructor Led</th>
#     </tr>
#     <tr>
#         <td align='left' valign='top'>
#           <h4 align='left'>Course Welcome</h4>
#           <h4 align='left'>M1: Intro to Interactive Viz Frameworks (Shiny)</h4>
#           <h4 align='left'>M2: Customizing Interactive Viz</h4>
#         </td>
#         <td apgn='left' valign='top'>
#           <h4 align='left'>M3: Cognition &amp; Visual Perception</h4>
#           <h4 align='left'>M4: Visualization &amp; Human-centered Design</h4>
#         </td>
#         <td apgn='left' valign='top'>
#           <h4 align='left'>Review, Exercises 1-4</h4>
#           <h4 align='left'>M5: Human-centered Design &amp; Evaluation</h4>
#         </td>
#         <td apgn='left' valign='top'>
#           <h4 align='left'>M6: Interactive Map Interfaces</h4>
#           <h4 align='left'>M7: Interactive Visualizations with D3</h4>
#         </td>
#         <td apgn='left' valign='top'>
#           <h4 align='left'>M8: Network Visualization</h4>
#           <h4 align='left'>Concept Review</h4>
#           <h4 align='left'>Final Project</h4>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
#
# ## Course Conduct, Non-Discrimination Notice
#
#
# Title IX is a comprehensive federal law that prohibits discrimination on the basis of sex in any federally funded education program or activity. The principal objective of Title IX is to avoid the use of federal money to support sex discrimination in education programs and to provide individual citizens effective protection against those practices. Title IX applies, with a few specific exceptions, to all aspects of federally funded education programs or activities. In addition to traditional educational institutions such as colleges, universities, and elementary and secondary schools, Title IX also applies to any education or training program operated by a recipient of federal financial assistance.
#
# Additional information is avaiable at: https://www.justice.gov/crt/overview-title-ix-education-amendments-1972-20-usc-1681-et-seq
#
# Additionally, the [No FEAR Act](http://prhome.defense.gov/Portals/52/Documents/nofear/NoFearAct.pdf) is intended to reduce the incidence of workplace discrimination within the federal government by making agencies and departments more accountable.
#
# The University of Missouri is committed to creating an inclusive and diverse community where everyone is welcome.
#
# If you have concerns regarding to antidiscrimination related to Title IX or No FEAR Act, please contact the appropriate indivuals below for University of Missouri or NGA,respectively.
#
#
# <table >
# <tr><th>University of Missouri</th><th>National Geospatial Intelligence Agency</th></tr>
# <tr><td valing='top'>
#     <strong>Ellen Eardley</strong><br/>
#     Assistant Vice Provost for Civil Rights and Title IX<br/>
#     202 Jesse Hall<br/>
#     University of Missouri<br/>
#     Columbia, MO 65211<br/>
#     573-882-3880<br/>
#     573-882-2824<br/>
#     EardleyE@missouri.edu<br/>
# </td>
# <td valing='top'>
#     <strong>Antenette Williams</strong><br/>
#     571-557-4106<br/>
#     Antenette.Williams@nga.mil<br/>
# <br/>
# </td>
# </tr>
# </table>
